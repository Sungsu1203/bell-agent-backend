# %%
from langchain_openai import ChatOpenAI

model=ChatOpenAI(model='gpt-4o-mini')
model.invoke("최근 로제가 발표한 신곡은 무엇인가?")
# Out:
# AIMessage(content='2023년 9월 16일에 블랙핑크의 로제가 "SESSION"이라는 신곡을 발표했습니다. 이 곡은 특별한 감정과 개인적인 이야기를 담고 있으며, 팬들 사이에서 큰 호응을 얻고 있습니다. 더 궁금한 점이 있으면 말씀해 주세요!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 68, 'prompt_tokens': 18, 'total_tokens': 86, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CHTbJd08dU2I0eMX2Gwh9zFKyaAMs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--138b498c-4ccc-4c9e-8f3c-158468dd6d0d-0', usage_metadata={'input_tokens': 18, 'output_tokens': 68, 'total_tokens': 86, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# %pip install -U duckduckgo-search
# Out:
# Collecting duckduckgo-search
#   Using cached duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in d:\gpt_agent_2025_book\venv\lib\site-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Using cached primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=5.3.0 in d:\gpt_agent_2025_book\venv\lib\site-packages (from duckduckgo-search) (6.0.1)
# Requirement already satisfied: colorama in d:\gpt_agent_2025_book\venv\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Using cached duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Using cached primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
# Installing collected packages: primp, duckduckgo-search
#
#    -------------------- ------------------- 1/2 [duckduckgo-search]
#    -------------------- ------------------- 1/2 [duckduckgo-search]
#    ---------------------------------------- 2/2 [duckduckgo-search]
#
# Successfully installed duckduckgo-search-8.1.1 primp-0.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.tools import DuckDuckGoSearchResults

search=DuckDuckGoSearchResults(results_separator=';\n')
docs=search.invoke("최근 로제가 발표한 신곡은 무엇인가?")

print(docs)
# Out:
# snippet: 로제가 전 세계에 알린 한국 술 게임 아파트, 어떻게 하는 건데? 복사. 공유., title: 로제가 전 세계에 알린 한국 술 게임 APT... | 얼루어 코리아 (Allure Korea), link: https://www.allurekorea.com/2024/10/20/로제가-전-세계에-알린-한국-술-게임-아파트-어떻게-하/;
# snippet: 걸그룹 블랙핑크의 로제가 빌보드 글로벌 차트 정상을 찍은 곡 ‘아파트’(APT.) 탄생 비화를 소개했다. 브루노 마스 쪽에 3곡의 협업곡 후보를 제시했는데, 브루노 마스가 ‘아파트’를 콕 집었다는 것이다., title: 로제가 보낸 3곡 중 ‘아파트’ 고른 브루노 마스…“끝내주네” | 한겨레, link: https://www.hani.co.kr/arti/international/international_general/1166261.html;
# snippet: 개드립. 즐겨찾기. 최근 . 최근 방문 게시판. 로제가 원하면 결혼식 할 수 있는 의외의 장소., title: 로제가 원하면 결혼식 할 수 있는 의외의 장소 - DogDrip.Net 개드립, link: https://www.dogdrip.net/606836628;
# snippet: 틱톡과 인스타그램은 그것으로 도배가 될거고 이번 곡을 기점으로 로제가 제니를 제치고 K POP 여제가 될 것이다., title: 블랙핑크 로제 신곡은 사실상 로제의 대관식이다 | 일베-일간베스트, link: https://www.ilbe.com/view/11554534319

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

question_answering_prompt=ChatPromptTemplate.from_messages(
    [
        (
        "system",
        "아래 context에 기반하여 사용자의 질문에 답변하라.:\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"),
    ]
)

document_chain=question_answering_prompt | model

# %%
from langchain.memory import ChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성
chat_history=ChatMessageHistory()

# 사용자 질문을 메모리에 저장
chat_history.add_user_message("요즘 로제가 발표한 신곡은 무엇인가?")

# 문서 검색하고 답변 생성
answer=document_chain.invoke(
    {
        "messages":chat_history.messages,
        "context":docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
# Out:
# content="로제가 발표한 신곡은 '아파트'(APT.)입니다. 이 곡은 블랙핑크의 로제가 빌보드 글로벌 차트에서 정상을 찍은 작품으로, 브루노 마스와의 협업으로 탄생한 곡입니다." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 425, 'total_tokens': 483, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CHTx6gEqSKmXSBrG6IztroMGLonYS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--b7d14279-c49c-4f93-86ea-55f703a2aa05-0' usage_metadata={'input_tokens': 425, 'output_tokens': 58, 'total_tokens': 483, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# DuckDuckGo API 래퍼를 사용하여 검색할 때 검색 매개변수를 설정하는 클래스 import
from langchain_community.utilities import DuckDuckGoSearchAPIWrapper

# 한국지역("kr-kr")을 기준, 최근 일주일("w") 내의 검색 결과를 가져오도록 초기화
wrapper=DuckDuckGoSearchAPIWrapper(region="kr-kr", time="w")

# %%
# 검색 기능을 위한 DuckDuckGoSearchResults 초기화
search=DuckDuckGoSearchResults(
    api_wrapper=wrapper,
    source="news",
    results_separator=';\n'
)

# %%
# '로제의 신곡 APT에 대한 반응'을 검색하고 결과를 docs에 저장
# docs=search.invoke("로제의 신곡 APT에 대한 반응")
docs=search.invoke("사법개혁에 대한 반응")

# 검색 결과 출력
print(docs)
# Out:
# snippet: 6일 전 — 사법개혁에 대한 전국 법원장들의 우려 표명에 민주당은 사법부가 자초한 자업자득이라고 비판 했습니다. 정청래 대표는 특히 사법부 독립을 강조한 조희대 대법원장을 ..., title: 여 “사법개혁 사법부가 자초”…야 “사법부 말살 시도”, link: https://news.kbs.co.kr/news/pc/view/view.do?ncd=8356851;
# snippet: 6일 전 — 전국 법원장들이 정부와 여당이 추진하는 사법개혁안에 공개적으로 우려하는 목소리를 냈다 . 정치 현안에 의견을 밝히기를 꺼리는 사법부가 정부안에 사실상 반대 입장 ..., title: “사법부 의견도 들어야” 목소리 낸 법관들, 사법개혁 우려한 ..., link: https://www.khan.co.kr/article/202509141610001;
# snippet: 5일 전 — 전국 법원장들이 정부와 여당이 추진하는 사법개혁안에 대해 우려하는 목소리를 냈다 . 정치 현안에 의견을 밝히기를 꺼리는 사법부가 정부안에 사실상 반대 입장을 표명한 ..., title: 사법부가 사법개혁 반대 나선 이유 “법관 목소리 외면”, link: https://www.khan.co.kr/article/202509142044015;
# snippet: 7일 전 — 국민의힘이 더불어민주당의 사법개혁 추진 에 대해 "정치적 목적이 다분한 개악"이라 비판했다. 13일 박성훈 수석대변인은 논평을 내고 '사법부는 입법부가 설정한 구조 ..., title: 국힘 "사법개혁, 정치적 목적 다분한 개악" 비판, link: https://www.joongang.co.kr/article/25366652?ac=vt

# %%
from langchain.memory import ChatMessageHistory

# 채팅 메시지를 저장할 메모리 객체 생성
chat_history=ChatMessageHistory()

# 사용자 질문을 메모리에 저장
# chat_history.add_user_message("로제의 신곡 APT에 대한 반응을 알려줘.")
chat_history.add_user_message("사법개혁에 대한 반응을 알려줘.")

# 문서 검색하고 답변 생성
answer=document_chain.invoke(
    {
        "messages":chat_history.messages,
        "context":docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
# Out:
# content='최근 사법개혁에 대한 반응은 다양합니다. 민주당은 전국 법원장들이 우려를 표명한 것에 대해 사법부가 자초한 일이라고 비판했습니다. 정청래 대표는 사법부의 독립성을 강조하며, 사법부가 과거의 문제를 스스로 초래한 것이라는 입장을 보였습니다.\n\n반면, 전국 법원장들은 정부와 여당이 추진하는 사법개혁안에 대해 공개적으로 우려를 나타내며, 정치 현안에 대한 입장을 밝히기 꺼리는 사법부가 사실상 정부안에 반대하는 입장을 표명했습니다. 이들은 특히 법관의 목소리를 외면한 것에 대한 불만을 드러냈습니다.\n\n또한, 국민의힘은 민주당의 사법개혁 추진이 정치적 목적이 다분한 "개악"이라고 비판하며 강한 반대 입장을 나타냈습니다. 이러한 점에서 사법개혁을 둘러싼 정치적 논란이 계속되고 있는 상황입니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 228, 'prompt_tokens': 477, 'total_tokens': 705, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CHd6NLym4hZNgnyMLVtuuOhvtEC4Q', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--76ead995-5aa2-4107-a7f6-c59ac126b61e-0' usage_metadata={'input_tokens': 477, 'output_tokens': 228, 'total_tokens': 705, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
# DuckDuckGo를 이용해 ytn.co.kr 웹 사이트에서 로제의 신곡 APT에 대한 분석을 검색
docs=search.invoke("site:ytn.co.kr 경주 APEC에 대한 뉴스")
print(docs)
# Out:
# snippet: 2 days ago · 조셉 윤 주한미국대사대리는 다음 달 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의에 도널드 트럼프 미국 대통령이 참석할 것임을 ..., title: [정치]조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사 | YTN, link: https://www.ytn.co.kr/_ln/0101_202509171537205972;
# snippet: 1 day ago · 경주 시내에 자리 잡은 대다수 숙박업소는 APEC 행사가 열리는 다음 달 27일부터 11월 1일까지 요금을 크게 올려받고 있습니다.제작 : 안진영, title: [YTNShorts]껑충 뛴 '경주 숙소값' | YTN, link: https://www.ytn.co.kr/_ln/0519_202509181044234815;
# snippet: 3 days ago · 조현 외교부 장관이 시진핑 중국 국가주석의 경주 APEC 정상회의 참석 여부와 관련해, 중국은 참석을 거의 확실하게 생각하는 것으로 알고 있다고 ..., title: [정치]조현 "중국, APEC 참석 거의 확실하게 생각하는 듯" | YTN, link: https://www.ytn.co.kr/_ln/0101_202509161613146408;
# snippet: 2 days ago · AD [앵커] 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의가 40여 일 앞으로 다가온 가운데 시설물 공사가 거의 마무리됐습니다., title: [전국]APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마..., link: https://www.ytn.co.kr/_ln/0115_202509172106138352

# %%
# 검색 결과의 링크들을 저장할 빈 리스트 초기화
links=[]

# 검색 결과를 세미콜론과 줄 바꿈 기준으로 분리하고, 각 결과 항목에서 링크 추출

for doc in docs.split(";\n"):
    print(doc)                          # 각 검색 결과 항목을 출력하여 확인
    link=doc.split("link:")[1].strip()  # 각 항목에서 'link:' 이후의 URL 부분만 추출
    links.append(link)                  # 추출한 링크를 리스트에 추가

# 모든 링크를 출력
print(links)
# Out:
# snippet: 2 days ago · 조셉 윤 주한미국대사대리는 다음 달 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의에 도널드 트럼프 미국 대통령이 참석할 것임을 ..., title: [정치]조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사 | YTN, link: https://www.ytn.co.kr/_ln/0101_202509171537205972
# snippet: 1 day ago · 경주 시내에 자리 잡은 대다수 숙박업소는 APEC 행사가 열리는 다음 달 27일부터 11월 1일까지 요금을 크게 올려받고 있습니다.제작 : 안진영, title: [YTNShorts]껑충 뛴 '경주 숙소값' | YTN, link: https://www.ytn.co.kr/_ln/0519_202509181044234815
# snippet: 3 days ago · 조현 외교부 장관이 시진핑 중국 국가주석의 경주 APEC 정상회의 참석 여부와 관련해, 중국은 참석을 거의 확실하게 생각하는 것으로 알고 있다고 ..., title: [정치]조현 "중국, APEC 참석 거의 확실하게 생각하는 듯" | YTN, link: https://www.ytn.co.kr/_ln/0101_202509161613146408
# snippet: 2 days ago · AD [앵커] 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의가 40여 일 앞으로 다가온 가운데 시설물 공사가 거의 마무리됐습니다., title: [전국]APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마..., link: https://www.ytn.co.kr/_ln/0115_202509172106138352
# ['https://www.ytn.co.kr/_ln/0101_202509171537205972', 'https://www.ytn.co.kr/_ln/0519_202509181044234815', 'https://www.ytn.co.kr/_ln/0101_202509161613146408', 'https://www.ytn.co.kr/_ln/0115_202509172106138352']

# %%
# 랭체인의 WebBaseLoader를 사용하여 웹 페이지의 내용 불러오기
from langchain_community.document_loaders import WebBaseLoader

# WebBaseLoader 객체를 생성. 'links'는 웹 페이지 URL 목록을 담고 있는 변수
# bs_get_text_kwargs는 BeautifulSoup의 get_text() 메서드에 전달될 추가 인자

loader=WebBaseLoader(
    web_paths=links,    # 웹 페이지의 링크 목록을 지정
    bs_get_text_kwargs={
        "strip": True   # 웹 페이지에서 텍스트를 가져올 때 앞뒤의 공백 제거
    },
)

# 비동기로 웹 페이지의 내용을 로드하고, 각 문서를 page_contents 리스트에 추가
page_contents=[]            # 각 페이지의 내용을 저장할 리스트
async for doc in loader.alazy_load():
    page_contents.append(doc)   # 불러온 문서를 page_contents 리스트에 추가

# page_contents에 있는 각 웹 페이지의 내용 출력
for content in page_contents:
    print(content)              # 웹 페이지의 내용 출력
    print('---------------')    # 웹 페이지를 구분하는 구분선 출력
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Fetching pages: 100%|##########| 4/4 [00:00<00:00, 24.85it/s]
# page_content='[정치]조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사 | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북트위터밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법TV프로그램프로그램별날짜별시청자의견장애인 서비스검색하기조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사2025.09.17. 오후 3:37.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD조셉 윤 주한미국대사대리는 다음 달 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의에 도널드 트럼프 미국 대통령이 참석할 것임을 시사했습니다.윤 대사대리는 한미동맹 콘퍼런스 기조연설에서 지난달 한미 양국 대통령이 성공적인 정상회담을 가졌다면서 경주 APEC에서도 만날 것이라고 말했습니다.트럼프 대통령이 경주 APEC 정상회의 참석을 공식 발표하지는 않았지만, 미 당국자들도 기정사실화 하는 분위기입니다.윤 대사대리는 또, 최근 미 이민 당국의 한국인 노동자 체포 사태와 관련해 동맹 홀대론이 제기되는 것을 의식한 듯 한미동맹은 어느 때보다 강력하다고 강조하기도 했습니다.YTN 홍선기 (sunki0524@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]정치기사목록 전체보기풀려났지만 여전히 '부글부글'...협상 지렛대 될까?국민의힘 5년 8개월 만에 장외로...'경부선 투쟁' 과제는?정동영 "9·19 군사합의 올해 선제적 복원돼야"...북은 무기 성능시험국힘, '조희대 의혹' 제기 서영교·부승찬 고발키로YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고경품이벤트채널 안내리더스뉴스레터위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0101_202509171537205972', 'title': '[정치]조셉 윤 "한미 정상 APEC서 만날 것"...트럼프 방한 시사 | YTN', 'description': '조셉 윤 주한미국대사대리는 다음 달 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의에 도널드 트럼프 미국 대통령이 참석할 것임을 시사했습니다.윤 대사대리는 ...', 'language': 'ko'}
# ---------------
# page_content='[YTNShorts]껑충 뛴 '경주 숙소값' | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램껑충 뛴 '경주 숙소값'검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북트위터밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법TV프로그램프로그램별날짜별시청자의견장애인 서비스검색하기껑충 뛴 '경주 숙소값'2025.09.18. 오전 10:44.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD경주 시내에 자리 잡은 대다수 숙박업소는 APEC 행사가 열리는 다음 달 27일부터 11월 1일까지 요금을 크게 올려받고 있습니다.제작 : 안진영[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고경품이벤트채널 안내리더스뉴스레터위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0519_202509181044234815', 'title': "[YTNShorts]껑충 뛴 '경주 숙소값' | YTN", 'description': '경주 시내에 자리 잡은 대다수 숙박업소는 APEC 행사가 열리는 다음 달 27일부터 11월 1일까지 요금을 크게 올려받고 있습니다.제작 : 안진영', 'language': 'ko'}
# ---------------
# page_content='[정치]조현 "중국, APEC 참석 거의 확실하게 생각하는 듯" | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램조현 "중국, APEC 참석 거의 확실하게 생각하는 듯"검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북트위터밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법TV프로그램프로그램별날짜별시청자의견장애인 서비스검색하기조현 "중국, APEC 참석 거의 확실하게 생각하는 듯"2025.09.16. 오후 4:13.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD조현 외교부 장관이 시진핑 중국 국가주석의 경주 APEC 정상회의 참석 여부와 관련해, 중국은 참석을 거의 확실하게 생각하는 것으로 알고 있다고 말했습니다.조 장관은 오늘(16일) 국회 대정부질문에 출석해, 중국 내부 사정이라 확정 여부는 알 수 없다면서도 이같이 밝혔습니다.조 장관은 내일(17일) 취임 뒤 처음으로 중국을 찾아 한중 외교장관 회담을 진행하는데, 이 자리에서 관련 논의가 이어질 것으로 보입니다.YTN 황보혜경 (bohk1013@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]정치기사목록 전체보기풀려났지만 여전히 '부글부글'...협상 지렛대 될까?국민의힘 5년 8개월 만에 장외로...'경부선 투쟁' 과제는?정동영 "9·19 군사합의 올해 선제적 복원돼야"...북은 무기 성능시험국힘, '조희대 의혹' 제기 서영교·부승찬 고발키로YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고경품이벤트채널 안내리더스뉴스레터위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0101_202509161613146408', 'title': '[정치]조현 "중국, APEC 참석 거의 확실하게 생각하는 듯" | YTN', 'description': '조현 외교부 장관이 시진핑 중국 국가주석의 경주 APEC 정상회의 참석 여부와 관련해, 중국은 참석을 거의 확실하게 생각하는 것으로 알고 있다고 말했습니다.조 장관은 오...', 'language': 'ko'}
# ---------------
# page_content='[전국]APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마쳐" | YTN메뉴 바로가기본문 바로가기푸터 바로가기닫기YTNYTN브랜드채널YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN world남산서울타워장애인 서비스제보LIVE로그인회원가입로그아웃회원정보변경정치경제사회전국국제문화스포츠연예비즈날씨이슈시리즈TV프로그램APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마쳐"검색검색하기닫기많이 본 뉴스LIVE공유공유하기닫기페이스북트위터밴드카카오톡복사하기전체메뉴YTN닫기홈최신뉴스LIVE제보하기뉴스정치과학경제문화사회스포츠전국연예국제비즈날씨게임이슈속보단독재난시리즈북한탐사경제PICK짤막상식와이즈픽자막뉴스뉴스모아제보영상와이파일운세앵커리포트나이트포커스지금이뉴스이게웬날리지Y녹취록당.점.사재난방송은 YTN데이터저널리즘반려병법TV프로그램프로그램별날짜별시청자의견장애인 서비스검색하기APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마쳐"2025.09.17. 오후 9:06.댓글글자크기설정글자 크기 설정닫기가가가가가공유하기공유하기닫기페이스북엑스밴드카카오톡복사하기인쇄하기AD[앵커]경주에서 열리는 아시아태평양경제협력체, APEC 정상회의가 40여 일 앞으로 다가온 가운데 시설물 공사가 거의 마무리됐습니다.이제 마지막 점검과 함께 우리나라의 우수한 기술과 문화를 전 세계에 선보일 준비만 남았습니다.이윤재 기자가 현장에 다녀왔습니다.[기자]국립 경주박물관 마당에 웅장한 목조 건물이 자리 잡았습니다.마무리 작업이 한창인 APEC 정상회의 만찬장입니다.신라를 상징하는 '금관' 등 문화재를 배경으로 21개 나라 정상이 만찬을 즐길 예정입니다.주요 시설 공사는 대부분 막바지에 접어들었습니다.정상회의가 열리는 이곳 화백컨벤션센터는 보안 이유로 출입을 통제한 채로 외벽을 단장하는 작업이 이뤄지고 있습니다.바로 옆으로 각국 기자 수천 명이 취재할 미디어센터도 완공을 앞두고 있습니다.이제 시설물을 꼼꼼히 점검하고, 실내를 꾸미는 일만 남았습니다.[김종순 / APEC 준비지원단 운영지원과장 : 미디어센터하고, 전시장 같은 경우에는 95% 가까이…. 마무리 단계에 있어서 조만간 시설이 완료되면 안에 시설들 들어가는 것, 그런 것들을 시운전하는 단계가 남아 있습니다.]경상북도는 대통령실 경호안전통제단 등과 함께 회의를 열고, 추진 상황과 보안 문제를 미리 점검했습니다.이철우 도지사는 앞으로 정상회의가 열릴 때까지 40여 일 동안 경주에 머무르며 빈틈없이 APEC을 챙길 계획입니다.특히 우리나라의 저력을 보여줄 기술 전시와 문화 공연 준비에 집중할 방침입니다.[이철우 / 경상북도지사 : 손님맞이에 전혀 손색이 없도록 만들고, 대한민국 한류를 한껏 보여줄 수 있는 프로그램을 만들도록 하는 데 최선을 다하겠습니다.대한민국이 초일류 국가라는 것을 보여주는 그런 계기가 되리라 생각하고…. 2005년 부산에 이어 20년 만에 우리나라에서 열리는 APEC 정상회의.전 세계에 달라진 한국의 위상을 보여줄 준비가 순조롭게 진행되고 있습니다.YTN 이윤재입니다.VJ: 윤예온YTN 이윤재 (lyj1025@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]전국기사목록 전체보기'이주민 10만 명 시대' 안산, 다문화 정책 선도한다"햇빛·바람으로 먹고 산다"...'에너지 연금' 꿈꾸는 전남학생이 직접 키우는 희귀식물...'학교 생태숲' 눈길되살아난 '크루즈 관광'...젊은 세대 승객도 증가YTN 미디어그룹YTN 회사소개INSIDE YTNYTN 사이언스YTN 라디오YTN2YTN dmbYTN worldYTN서울타워저널리즘 연구소약관 및 정책이용약관개인정보처리방침청소년보호정책기사배열 기본방침방송편성규약윤리강령시청자실시청자의견시청자 비평 플러스시청자 위원회고충처리위원회사이버감사실견학 신청성폭력신고센터알립니다공지사항공고채용공고경품이벤트채널 안내리더스뉴스레터위치 및 연락처이용 도움말광고 및 비즈니스TV광고큐톤시간표인터넷 · 모바일 광고사업 제휴동영상 뉴스 판매오디오 음원 판매뉴스 · 프로그램 공급YTN㈜와이티엔서울특별시 마포구 상암산로 76 (상암동)대표전화: 02-398-8000팩스: 02-398-8129사업자등록번호: 102-81-32883Copyright (c) YTN. All rights reserved. 무단 전재, 재배포 및 AI 데이터 활용 금지맨위로' metadata={'source': 'https://www.ytn.co.kr/_ln/0115_202509172106138352', 'title': '[전국]APEC 시설물 공사 대부분 마무리..."한국 위상 보여줄 준비 마쳐" | YTN', 'description': '경주에서 열리는 아시아태평양경제협력체, APEC 정상회의가 40여 일 앞으로 다가온 가운데 시설물 공사가 거의 마무리됐습니다.이제 마지막 점검과 함께 우리나라의 우수한...', 'language': 'ko'}
# ---------------

# %%
import requests
from bs4 import BeautifulSoup

# 주어진 URL에서 기사 텍스트를 가져오는 함수
def get_article_text(url):
    try:
        # URL에 GET 요청을 보냄
        response=requests.get(url)
        # 요청이 성공하지 못하면 예외를 발생시킴
        response.raise_for_status()

        # BeautifulSoup을 사용하여 HTML 내용 파싱
        soup=BeautifulSoup(response.content,'html.parser')

        # 클래스가 'story-news article'인 <article> 태그 찾기
        article=soup.find('article', class_='story-news article')

        # 기사를 찾았다면 그 텍스트를 반환
        if article:
            return article.get_text(strip=True)
        else:
            try:
                if soup.find('article'):
                    return soup.find('article').get_text(strip=True)
                elif soup.find('div',id='CmAdContent'):
                    return soup.find('div',id='CmAdContent').get_text(strip=True)
            except:
                return "기사 내용을 찾을 수 없습니다."
            
    # 요청이 실패할 경우 예외 처리
    except requests.exceptions.RequestException as e:
        return f"URL을 가져오는 중 오류 발생: {e}"

# %%
# URL 목록의 각 링크를 반복하면서 기사 텍스트 출력
articles=[]
for link in links:
    print(f"URL: {link}\n")
    article_text=get_article_text(link)
    print(f"Content:\n{article_text}")
    print("----------------------------------")
    articles.append(article_text)
# Out:
# URL: https://www.ytn.co.kr/_ln/0101_202509171537205972
#
# Content:
# 조셉 윤 주한미국대사대리는 다음 달 경주에서 열리는 아시아태평양경제협력체, APEC 정상회의에 도널드 트럼프 미국 대통령이 참석할 것임을 시사했습니다.윤 대사대리는 한미동맹 콘퍼런스 기조연설에서 지난달 한미 양국 대통령이 성공적인 정상회담을 가졌다면서 경주 APEC에서도 만날 것이라고 말했습니다.트럼프 대통령이 경주 APEC 정상회의 참석을 공식 발표하지는 않았지만, 미 당국자들도 기정사실화 하는 분위기입니다.윤 대사대리는 또, 최근 미 이민 당국의 한국인 노동자 체포 사태와 관련해 동맹 홀대론이 제기되는 것을 의식한 듯 한미동맹은 어느 때보다 강력하다고 강조하기도 했습니다.YTN 홍선기 (sunki0524@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ----------------------------------
# URL: https://www.ytn.co.kr/_ln/0519_202509181044234815
#
# Content:
# 경주 시내에 자리 잡은 대다수 숙박업소는 APEC 행사가 열리는 다음 달 27일부터 11월 1일까지 요금을 크게 올려받고 있습니다.제작 : 안진영[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ----------------------------------
# URL: https://www.ytn.co.kr/_ln/0101_202509161613146408
#
# Content:
# 조현 외교부 장관이 시진핑 중국 국가주석의 경주 APEC 정상회의 참석 여부와 관련해, 중국은 참석을 거의 확실하게 생각하는 것으로 알고 있다고 말했습니다.조 장관은 오늘(16일) 국회 대정부질문에 출석해, 중국 내부 사정이라 확정 여부는 알 수 없다면서도 이같이 밝혔습니다.조 장관은 내일(17일) 취임 뒤 처음으로 중국을 찾아 한중 외교장관 회담을 진행하는데, 이 자리에서 관련 논의가 이어질 것으로 보입니다.YTN 황보혜경 (bohk1013@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ----------------------------------
# URL: https://www.ytn.co.kr/_ln/0115_202509172106138352
#
# Content:
# [앵커]경주에서 열리는 아시아태평양경제협력체, APEC 정상회의가 40여 일 앞으로 다가온 가운데 시설물 공사가 거의 마무리됐습니다.이제 마지막 점검과 함께 우리나라의 우수한 기술과 문화를 전 세계에 선보일 준비만 남았습니다.이윤재 기자가 현장에 다녀왔습니다.[기자]국립 경주박물관 마당에 웅장한 목조 건물이 자리 잡았습니다.마무리 작업이 한창인 APEC 정상회의 만찬장입니다.신라를 상징하는 '금관' 등 문화재를 배경으로 21개 나라 정상이 만찬을 즐길 예정입니다.주요 시설 공사는 대부분 막바지에 접어들었습니다.정상회의가 열리는 이곳 화백컨벤션센터는 보안 이유로 출입을 통제한 채로 외벽을 단장하는 작업이 이뤄지고 있습니다.바로 옆으로 각국 기자 수천 명이 취재할 미디어센터도 완공을 앞두고 있습니다.이제 시설물을 꼼꼼히 점검하고, 실내를 꾸미는 일만 남았습니다.[김종순 / APEC 준비지원단 운영지원과장 : 미디어센터하고, 전시장 같은 경우에는 95% 가까이…. 마무리 단계에 있어서 조만간 시설이 완료되면 안에 시설들 들어가는 것, 그런 것들을 시운전하는 단계가 남아 있습니다.]경상북도는 대통령실 경호안전통제단 등과 함께 회의를 열고, 추진 상황과 보안 문제를 미리 점검했습니다.이철우 도지사는 앞으로 정상회의가 열릴 때까지 40여 일 동안 경주에 머무르며 빈틈없이 APEC을 챙길 계획입니다.특히 우리나라의 저력을 보여줄 기술 전시와 문화 공연 준비에 집중할 방침입니다.[이철우 / 경상북도지사 : 손님맞이에 전혀 손색이 없도록 만들고, 대한민국 한류를 한껏 보여줄 수 있는 프로그램을 만들도록 하는 데 최선을 다하겠습니다.대한민국이 초일류 국가라는 것을 보여주는 그런 계기가 되리라 생각하고…. 2005년 부산에 이어 20년 만에 우리나라에서 열리는 APEC 정상회의.전 세계에 달라진 한국의 위상을 보여줄 준비가 순조롭게 진행되고 있습니다.YTN 이윤재입니다.VJ: 윤예온YTN 이윤재 (lyj1025@ytn.co.kr)※ '당신의 제보가 뉴스가 됩니다'[카카오톡] YTN 검색해 채널 추가[전화] 02-398-8585[메일] social@ytn.co.kr[저작권자(c) YTN 무단전재, 재배포 및 AI 데이터 활용 금지]
# ----------------------------------

# %%
chat_history.add_user_message("경주 APEC에 대한 뉴스를 알려줘.")

# 문서 검색하고 답변 생성
answer=document_chain.invoke(
    {
        "messages":chat_history.messages,
        "context":docs,
    }
)

# 생성된 답변 메모리에 저장
chat_history.add_ai_message(answer)
print(answer)
# Out:
# content='경주에서 열리는 아시아태평양경제협력체(APEC) 정상회의에 대한 최근 뉴스는 다음과 같습니다:\n\n1. **참석 예정 인사**: 조셉 윤 주한미국대사대리는 도널드 트럼프 미국 대통령이 다음 달 경주에서 열리는 APEC 정상회의에 참석할 것이라고 밝혔습니다. 이는 한미 정상 간의 만남을 의미합니다.\n\n2. **숙박 요금 인상**: APEC 행사가 열리는 기간인 10월 27일부터 11월 1일까지 경주 시내 대부분의 숙박업소에서 요금이 크게 인상되고 있다는 보고가 있습니다. 많은 관광객들이 몰릴 것으로 예상되는 가운데, 숙소 가격이 껑충 뛰는 현상이 발생하고 있습니다.\n\n3. **중국의 참석 가능성**: 조현 외교부 장관은 시진핑 중국 국가주석의 APEC 참석 여부에 대해, 중국이 참석할 가능성이 높다고 언급했습니다.\n\n4. **시설물 공사 완료**: APEC 회의 준비가 한창이며, 시설물 공사는 대부분 마무리되었습니다. 이는 한국의 국제적 위상을 보여줄 준비에 대한 기대감을 나타냅니다.\n\n이러한 내용들을 통해 경주 APEC 정상회의가 임박했음을 알 수 있으며, 여러 나라의 고위 인사들이 참석할 예정인 만큼 관심이 집중되고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 305, 'prompt_tokens': 695, 'total_tokens': 1000, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CHe1IVKNQLLqbBqLargDgSkAgGhlP', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--f84f3416-2335-4492-b34b-4a7774a3511f-0' usage_metadata={'input_tokens': 695, 'output_tokens': 305, 'total_tokens': 1000, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
