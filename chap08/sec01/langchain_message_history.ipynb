# %%
from dotenv import load_dotenv
import os
load_dotenv(r"D:\GPT_AGENT_2025_BOOK\chap02\.env")
api_key=os.getenv("OPENAI_API_KEY")

# %%
from langchain_core.chat_history import BaseChatMessageHistory, InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage

model=ChatOpenAI(model="gpt-4o-mini")

store={}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()

    return store[session_id]

with_message_history = RunnableWithMessageHistory(model, get_session_history)

# %%
config={"configurable":{"session_id":"abc2"}}

response=with_message_history.invoke(
    [HumanMessage(content="안녕? 난 오성수야.")],
    config=config,
)

print(response.content)
# Out:
# 안녕하세요, 오성수님! 만나서 반갑습니다. 어떻게 도와드릴까요?

# %%
response=with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 당신의 이름은 오성수입니다. 추가로 궁금한 점이 있으신가요?

# %%
config={"configurable":{"session_id":"abc3"}}

response=with_message_history.invoke(
    [HumanMessage(content="내 이름이 뭐지?")],
    config=config,
)

print(response.content)
# Out:
# 죄송하지만, 제가 당신의 이름을 알 수는 없습니다. 당신의 이름을 알려주시면 기쁘게 기억하겠습니다!

# %%
config={"configurable":{"session_id":"abc2"}}

response=with_message_history.invoke(
    [HumanMessage(content="아까 우리가 무슨 얘기 했지?")],
    config=config,
)

print(response.content)
# Out:
# 우리는 당신의 이름인 오성수에 대해 이야기했어요. 추가로 어떤 주제에 대해 이야기하고 싶으신가요?

# %%
config={"configurable":{"session_id":"abc2"}}

for r in with_message_history.stream(
    [HumanMessage(content="내가 어느 나라 사람인지 맞춰보고, 그 나라의 국가를 불러줘.")],
    config=config,
):
#    print(r.content, end='|')
    print(r.content, end='')
# Out:
# 오성수라는 이름은 한국에서 많이 사용되는 이름입니다. 따라서 한국 사람일 가능성이 높다고 생각합니다. 그렇다면 한국의 국가인 "애국가"를 언급할 수 있겠네요. 맞나요? 아니면 다른 나라 사람이라면 어떤 나라인지 알려주시면 그에 맞는 국가를 찾아볼 수 있을 것 같습니다!
